# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
abalone= pd.read_csv("Downloads/abalone.data.csv")

# %%
abalone.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weightShucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095                      0.5140          0.2245
# 1   M   0.350     0.265   0.090                      0.2255          0.0995
# 2   F   0.530     0.420   0.135                      0.6770          0.2565
# 3   M   0.440     0.365   0.125                      0.5160          0.2155
# 4   I   0.330     0.255   0.080                      0.2050          0.0895
#
#    Shell weight  Rings  Age
# 0        0.1010  0.150   15
# 1        0.0485  0.070    7
# 2        0.1415  0.210    9
# 3        0.1140  0.155   10
# 4        0.0395  0.055    7

# %%
abalone.shape
# Out:
# (4177, 9)

# %%
abalone.isnull().sum()
# Out:
# Sex                           0
# Length                        0
# Diameter                      0
# Height                        0
# Whole weightShucked weight    0
# Viscera weight                0
# Shell weight                  0
# Rings                         0
# Age                           0
# dtype: int64

# %%
abalone.duplicated().sum()
# Out:
# np.int64(0)

# %%
abalone.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Sex                         4177 non-null   object
#  1   Length                      4177 non-null   float64
#  2   Diameter                    4177 non-null   float64
#  3   Height                      4177 non-null   float64
#  4   Whole weightShucked weight  4177 non-null   float64
#  5   Viscera weight              4177 non-null   float64
#  6   Shell weight                4177 non-null   float64
#  7   Rings                       4177 non-null   float64
#  8   Age                         4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
abalone.describe()
# Out:
#             Length     Diameter       Height  Whole weightShucked weight  \
# count  4177.000000  4177.000000  4177.000000                 4177.000000
# mean      0.523992     0.407881     0.139516                    0.828742
# std       0.120093     0.099240     0.041827                    0.490389
# min       0.075000     0.055000     0.000000                    0.002000
# 25%       0.450000     0.350000     0.115000                    0.441500
# 50%       0.545000     0.425000     0.140000                    0.799500
# 75%       0.615000     0.480000     0.165000                    1.153000
# max       0.815000     0.650000     1.130000                    2.825500
#
#        Viscera weight  Shell weight        Rings          Age
# count     4177.000000   4177.000000  4177.000000  4177.000000
# mean         0.359367      0.180594     0.238831     9.933684
# std          0.221963      0.109614     0.139203     3.224169
# min          0.001000      0.000500     0.001500     1.000000
# ...

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
abalone = pd.get_dummies(abalone, columns=['Sex'], prefix=['Sex'])

# %%
corr = abalone.corr()

# %%
sns.heatmap(corr,annot=True,cbar=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.histplot(abalone['Sex_I'],bins=20)
# Out:
# <Axes: xlabel='Sex_I', ylabel='Count'>

# %%
print(abalone.columns)
# Out:
# Index(['Length', 'Diameter', 'Height', 'Whole weightShucked weight',
#        'Viscera weight', 'Shell weight', 'Rings', 'Age', 'Sex_F', 'Sex_I',
#        'Sex_M'],
#       dtype='object')

# %%
abalone['Sex_F']= abalone['Sex_F'].map({"M":0,"F":1,"I":2})

# %%
abalone['Sex_F'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
sns.histplot(abalone['Rings'],bins=20)
# Out:
# <Axes: xlabel='Rings', ylabel='Count'>

# %%
abalone['Rings'].value_counts()
# Out:
# Rings
# 0.2750    43
# 0.2500    42
# 0.2650    40
# 0.3150    40
# 0.1850    40
#           ..
# 0.0060     1
# 0.6460     1
# 0.5010     1
# 0.3295     1
# 0.0920     1
# Name: count, Length: 926, dtype: int64

# %%
sns.scatterplot(x='Length',y='Rings',data=abalone)
# Out:
# <Axes: xlabel='Length', ylabel='Rings'>

# %%
X= abalone.iloc[:,:-1]
y=abalone.iloc[:,-1]

# %%
X.shape
# Out:
# (4177, 10)

# %%
y.shape
# Out:
# (4177,)

# %%
X= abalone.drop('Rings',axis=1)
y=abalone['Rings']

# %%
pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_train.shape
# Out:
# (3341, 10)

# %%
X_test.shape
# Out:
# (836, 10)

# %%
X_train
# Out:
#       Length  Diameter  Height  Whole weightShucked weight  Viscera weight  \
# 82     0.520     0.425   0.165                      0.9885          0.3960
# 1161   0.610     0.485   0.160                      1.0145          0.5315
# 3132   0.685     0.530   0.170                      1.5105          0.7385
# 3672   0.595     0.440   0.135                      0.9640          0.5005
# 68     0.475     0.390   0.120                      0.5305          0.2135
# ...      ...       ...     ...                         ...             ...
# 3335   0.425     0.325   0.135                      0.3820          0.1465
# 1099   0.500     0.375   0.140                      0.5495          0.2480
# 2514   0.470     0.370   0.110                      0.5555          0.2500
# 3606   0.510     0.375   0.110                      0.5805          0.2865
# 2575   0.500     0.375   0.145                      0.6215          0.2740
#
#       Shell weight  Age  Sex_F  Sex_I  Sex_M
# ...
